# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ydata_profiling import ProfileReport
import warnings
warnings.filterwarnings('ignore')

# Load training data
test_df = pd.read_csv(r'C:\Users\Zeina\House_Pricing\data\raw\test.csv')
train_df = pd.read_csv(r'C:\Users\Zeina\House_Pricing\data\raw\train.csv')

print(f"Training data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")

# Generate comprehensive profiling report
profile = ProfileReport(
    train_df,
    title="House Prices - Training Data Profile",
    explorative=True,

)

# Save profiling report
profile.to_file("../data/profiling_report.html")
print("✓ Profiling report saved to data/profiling_report.html")
# Out:
# Training data shape: (1460, 81)
# Test data shape: (1459, 80)
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ Profiling report saved to data/profiling_report.html
